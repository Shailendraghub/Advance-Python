# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/placement (1).csv")

# %%
data
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
data.head() # top 5 data
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
data.tail()  #  bottom 5 data.
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
data.describe()  # statically view of data.
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
data.info()   #data type information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
data.loc[1:3, ['cgpa','placed']] # loc [row_range,names]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
top_left_corner_df=data.iloc[:4 ,:3]  # iloc[row_range,column_range]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
data.shape
# Out:
# (100, 3)

# %%
s=data.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p=data.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b=data.empty  ## it returns true if there any missing data in dataframe otherwise returns false.
b
# Out:
# False

# %%
data.isnull().sum()  # for cheking missing values
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
data.dropna() ## for remove missing row.
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
i=data.ndim  # number of axed(it is 2)
i
# Out:
# 2

# %%
t=data.shape  # shape=n(rows),n(columns)
t
# Out:
# (100, 3)

# %%
d=data.size  # row count* column count
d
# Out:
# 300

# %%
a=data.values  # get a numpy array of df
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df=data.copy()

# %%
p=data.sort_values(by ="resume_score")
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
data['Cgpa']=data['cgpa'].astype(int)

# %%
data
# Out:
#     resume_score  placed  Cgpa
# 0              6       1     8
# 1              5       0     6
# 2              8       1     8
# 3              7       1     6
# 4              7       1     7
# ..           ...     ...   ...
# 95             6       0     6
# 96             7       1     8
# 97             7       0     6
# 98             5       1     8
# 99             6       0     6
#
# [100 rows x 3 columns]

# %%
data=data.drop(columns=['cgpa'])

# %%
p=data

# %%
p['Cgpa']=p['Cgpa'].astype(int)

# %%
p
# Out:
#     resume_score  placed  Cgpa
# 0              6       1     8
# 1              5       0     6
# 2              8       1     8
# 3              7       1     6
# 4              7       1     7
# ..           ...     ...   ...
# 95             6       0     6
# 96             7       1     8
# 97             7       0     6
# 98             5       1     8
# 99             6       0     6
#
# [100 rows x 3 columns]

# %%
data
# Out:
#     resume_score  placed  Cgpa
# 0              6       1     8
# 1              5       0     6
# 2              8       1     8
# 3              7       1     6
# 4              7       1     7
# ..           ...     ...   ...
# 95             6       0     6
# 96             7       1     8
# 97             7       0     6
# 98             5       1     8
# 99             6       0     6
#
# [100 rows x 3 columns]

# %%
p['resume_score']=p['resume_score'].astype(int)

# %%
p
# Out:
#     resume_score  placed  Cgpa
# 0              6       1     8
# 1              5       0     6
# 2              8       1     8
# 3              7       1     6
# 4              7       1     7
# ..           ...     ...   ...
# 95             6       0     6
# 96             7       1     8
# 97             7       0     6
# 98             5       1     8
# 99             6       0     6
#
# [100 rows x 3 columns]

# %%
data['Cgpa']=data['Cgpa'].add(4)
data
# Out:
#     resume_score  placed  Cgpa
# 0              6       1    16
# 1              5       0    14
# 2              8       1    16
# 3              7       1    14
# 4              7       1    15
# ..           ...     ...   ...
# 95             6       0    14
# 96             7       1    16
# 97             7       0    14
# 98             5       1    16
# 99             6       0    14
#
# [100 rows x 3 columns]

# %%
data['resume_score']=data['resume_score'].add(4)
data
# Out:
#     resume_score  placed  Cgpa
# 0             10       1    16
# 1              9       0    14
# 2             12       1    16
# 3             11       1    14
# 4             11       1    15
# ..           ...     ...   ...
# 95            10       0    14
# 96            11       1    16
# 97            11       0    14
# 98             9       1    16
# 99            10       0    14
#
# [100 rows x 3 columns]

# %%
s=df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p=data.max()
p
# Out:
# resume_score    13
# placed           1
# Cgpa            17
# dtype: int64

# %%
q=data.min()
q
# Out:
# resume_score     8
# placed           0
# Cgpa            13
# dtype: int64

# %%
r=data['Cgpa'].mean()
r
# Out:
# 14.47

# %%
r=data['resume_score'].median()
r
# Out:
# 11.0

# %%
g=data.filter(items=['Cgpa','placed'])
g
data[['Cgpa','placed']]
# Out:
#     Cgpa  placed
# 0     16       1
# 1     14       0
# 2     16       1
# 3     14       1
# 4     15       1
# ..   ...     ...
# 95    14       0
# 96    16       1
# 97    14       0
# 98    16       1
# 99    14       0
#
# [100 rows x 2 columns]

# %%
s=data.filter(items=[3,4],axis =0)  # axis=0 means row wise operation.
s
# Out:
#    resume_score  placed  Cgpa
# 3            11       1    14
# 4            11       1    15

# %%
s=data.rename(columns={'Cgpa':'updated_cgpa',
                       'resume_score':"semester_marks"})
s
# Out:
#     semester_marks  placed  updated_cgpa
# 0               10       1            16
# 1                9       0            14
# 2               12       1            16
# 3               11       1            14
# 4               11       1            15
# ..             ...     ...           ...
# 95              10       0            14
# 96              11       1            16
# 97              11       0            14
# 98               9       1            16
# 99              10       0            14
#
# [100 rows x 3 columns]

# %%
data=data.rename(columns={'Cgpa':'cgpa',
                       'resume_score':"semester_marks"})
data
# Out:
#     semester_marks  placed  cgpa
# 0               10       1    16
# 1                9       0    14
# 2               12       1    16
# 3               11       1    14
# 4               11       1    15
# ..             ...     ...   ...
# 95              10       0    14
# 96              11       1    16
# 97              11       0    14
# 98               9       1    16
# 99              10       0    14
#
# [100 rows x 3 columns]

# %%
s=data.rename(columns={'Cgpa':'updated_cgpa',
                       'resume_score':"semester_marks"})
s
# Out:
#     semester_marks  placed  cgpa
# 0               10       1    16
# 1                9       0    14
# 2               12       1    16
# 3               11       1    14
# 4               11       1    15
# ..             ...     ...   ...
# 95              10       0    14
# 96              11       1    16
# 97              11       0    14
# 98               9       1    16
# 99              10       0    14
#
# [100 rows x 3 columns]

# %%
data.columns
# Out:
# Index(['semester_marks', 'placed', 'cgpa'], dtype='object')

# %%
data['half']=data['cgpa'].where(df['cgpa']>7,other=0)
data.head(10)
# Out:
#    semester_marks  placed  cgpa  half
# 0              10       1    16    16
# 1               9       0    14     0
# 2              12       1    16    16
# 3              11       1    14     0
# 4              11       1    15    15
# 5              10       1    16    16
# 6              11       0    13     0
# 7              10       0    14     0
# 8              10       0    14     0
# 9              11       1    15    15

# %%
df=pd.read_csv("/content/covid_toy (2).csv")

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].map({"Female":0, "Male":1})

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60       1  103.0    Mild    Kolkata        No
# 1    27       1  100.0    Mild      Delhi       Yes
# 2    42       1  101.0    Mild      Delhi        No
# 3    31       0   98.0    Mild    Kolkata        No
# 4    65       0  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12       0  104.0    Mild  Bangalore        No
# 96   51       0  101.0  Strong    Kolkata       Yes
# 97   20       0  101.0    Mild  Bangalore        No
# 98    5       0   98.0  Strong     Mumbai        No
# 99   10       0   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df['cough'] = df['cough'].map({"Mild":0,
                               "Strong":1})

# %%
df
# Out:
#     age  gender  fever  cough       city has_covid
# 0    60       1  103.0      0    Kolkata        No
# 1    27       1  100.0      0      Delhi       Yes
# 2    42       1  101.0      0      Delhi        No
# 3    31       0   98.0      0    Kolkata        No
# 4    65       0  101.0      0     Mumbai        No
# ..  ...     ...    ...    ...        ...       ...
# 95   12       0  104.0      0  Bangalore        No
# 96   51       0  101.0      1    Kolkata       Yes
# 97   20       0  101.0      0  Bangalore        No
# 98    5       0   98.0      1     Mumbai        No
# 99   10       0   98.0      1    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
df['has_covid'] = df['has_covid'].map({"No":0,
                               "Yes":1})

# %%
df
# Out:
#     age  gender  fever  cough       city  has_covid
# 0    60       1  103.0      0    Kolkata          0
# 1    27       1  100.0      0      Delhi          1
# 2    42       1  101.0      0      Delhi          0
# 3    31       0   98.0      0    Kolkata          0
# 4    65       0  101.0      0     Mumbai          0
# ..  ...     ...    ...    ...        ...        ...
# 95   12       0  104.0      0  Bangalore          0
# 96   51       0  101.0      1    Kolkata          1
# 97   20       0  101.0      0  Bangalore          0
# 98    5       0   98.0      1     Mumbai          0
# 99   10       0   98.0      1    Kolkata          1
#
# [100 rows x 6 columns]

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#               age      gender       fever       cough  has_covid
# count  100.000000  100.000000   90.000000  100.000000     100.00
# mean    44.220000    0.410000  100.844444    0.380000       0.45
# std     24.878931    0.494311    2.054926    0.487832       0.50
# min      5.000000    0.000000   98.000000    0.000000       0.00
# 25%     20.000000    0.000000   99.000000    0.000000       0.00
# 50%     45.000000    0.000000  101.000000    0.000000       0.00
# 75%     66.500000    1.000000  102.750000    1.000000       1.00
# max     84.000000    1.000000  104.000000    1.000000       1.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    int64
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    int64
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 4.8+ KB

# %%
df.shape
# Out:
# (100, 6)

# %%
df.size
# Out:
# 600

# %%
df.dtypes
# Out:
# age            int64
# gender         int64
# fever        float64
# cough          int64
# city          object
# has_covid      int64
# dtype: object

# %%
df.loc[1:3, ['cough','fever']]
# Out:
#    cough  fever
# 1      0  100.0
# 2      0  101.0
# 3      0   98.0

# %%
top_left_corner_df=df.iloc[:4 ,:3]
top_left_corner_df
# Out:
#    age  gender  fever
# 0   60       1  103.0
# 1   27       1  100.0
# 2   42       1  101.0
# 3   31       0   98.0

# %%
s=df.count()
s
# Out:
# age          100
# gender       100
# fever         90
# cough        100
# city         100
# has_covid    100
# dtype: int64

# %%
s=df.min()
s
# Out:
# age                  5
# gender               0
# fever             98.0
# cough                0
# city         Bangalore
# has_covid            0
# dtype: object

# %%
s=df.max()
s
# Out:
# age              84
# gender            1
# fever         104.0
# cough             1
# city         Mumbai
# has_covid         1
# dtype: object

# %%
b=df.empty
b
# Out:
# False

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df.dropna()
# Out:
#     age  gender  fever  cough       city  has_covid
# 0    60       1  105.0      0    Kolkata          0
# 1    27       1  102.0      0      Delhi          1
# 2    42       1  103.0      0      Delhi          0
# 3    31       0  100.0      0    Kolkata          0
# 4    65       0  103.0      0     Mumbai          0
# ..  ...     ...    ...    ...        ...        ...
# 95   12       0  106.0      0  Bangalore          0
# 96   51       0  103.0      1    Kolkata          1
# 97   20       0  103.0      0  Bangalore          0
# 98    5       0  100.0      1     Mumbai          0
# 99   10       0  100.0      1    Kolkata          1
#
# [90 rows x 6 columns]

# %%
a=df.values
a
# Out:
# array([[60, 1, 103.0, 0, 'Kolkata', 0],
#        [27, 1, 100.0, 0, 'Delhi', 1],
#        [42, 1, 101.0, 0, 'Delhi', 0],
#        [31, 0, 98.0, 0, 'Kolkata', 0],
#        [65, 0, 101.0, 0, 'Mumbai', 0],
#        [84, 0, nan, 0, 'Bangalore', 1],
#        [14, 1, 101.0, 1, 'Bangalore', 0],
#        [20, 0, nan, 1, 'Mumbai', 1],
#        [19, 0, 100.0, 1, 'Bangalore', 0],
#        [64, 0, 101.0, 0, 'Delhi', 0],
#        [75, 0, nan, 0, 'Delhi', 0],
#        [65, 0, 98.0, 0, 'Mumbai', 1],
#        [25, 0, 99.0, 1, 'Kolkata', 0],
#        [64, 1, 102.0, 0, 'Bangalore', 1],
#        [51, 1, 104.0, 0, 'Bangalore', 0],
#        [70, 1, 103.0, 1, 'Kolkata', 1],
#        [69, 0, 103.0, 0, 'Kolkata', 1],
#        [40, 0, 98.0, 1, 'Delhi', 0],
#        [64, 0, 98.0, 0, 'Bangalore', 1],
#        [42, 0, nan, 1, 'Bangalore', 1],
#        [12, 1, 98.0, 1, 'Bangalore', 0],
#        [73, 1, 98.0, 0, 'Bangalore', 1],
#        [71, 0, 98.0, 1, 'Kolkata', 1],
#        [80, 0, 98.0, 0, 'Delhi', 1],
# ...

# %%
s=df.filter(items=[3,4],axis =0)
s
# Out:
#    age  gender  fever  cough     city  has_covid
# 3   31       0   98.0      0  Kolkata          0
# 4   65       0  101.0      0   Mumbai          0

# %%
df['fever']=df['fever'].add(2)
df
# Out:
#     age  gender  fever  cough       city  has_covid
# 0    60       1  105.0      0    Kolkata          0
# 1    27       1  102.0      0      Delhi          1
# 2    42       1  103.0      0      Delhi          0
# 3    31       0  100.0      0    Kolkata          0
# 4    65       0  103.0      0     Mumbai          0
# ..  ...     ...    ...    ...        ...        ...
# 95   12       0  106.0      0  Bangalore          0
# 96   51       0  103.0      1    Kolkata          1
# 97   20       0  103.0      0  Bangalore          0
# 98    5       0  100.0      1     Mumbai          0
# 99   10       0  100.0      1    Kolkata          1
#
# [100 rows x 6 columns]

# %%
p=df.sort_values(by ="age")
p
# Out:
#     age  gender  fever  cough       city  has_covid
# 98    5       0  100.0      1     Mumbai          0
# 75    5       1  104.0      0    Kolkata          1
# 88    5       0  102.0      0    Kolkata          0
# 59    6       0  106.0      0    Kolkata          1
# 77    8       0  103.0      0    Kolkata          0
# ..  ...     ...    ...    ...        ...        ...
# 35   82       0  104.0      1  Bangalore          0
# 72   83       0  103.0      0    Kolkata          0
# 53   83       1  100.0      0      Delhi          1
# 31   83       1  105.0      0    Kolkata          0
# 5    84       0    NaN      0  Bangalore          1
#
# [100 rows x 6 columns]

# %%
df
# Out:
#     age  gender  fever  cough       city  has_covid
# 0    60       1  105.0      0    Kolkata          0
# 1    27       1  102.0      0      Delhi          1
# 2    42       1  103.0      0      Delhi          0
# 3    31       0  100.0      0    Kolkata          0
# 4    65       0  103.0      0     Mumbai          0
# ..  ...     ...    ...    ...        ...        ...
# 95   12       0  106.0      0  Bangalore          0
# 96   51       0  103.0      1    Kolkata          1
# 97   20       0  103.0      0  Bangalore          0
# 98    5       0  100.0      1     Mumbai          0
# 99   10       0  100.0      1    Kolkata          1
#
# [100 rows x 6 columns]
