# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\Admin\\Desktop\\python advance (panda)\\newplacementdata.csv")

# %%
df.head(5)
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                    26       1
# 1  7.46                    38       1
# 2  7.54                    40       1
# 3  6.42                     8       1
# 4  7.23                    17       0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
sns.displot(df['cgpa'])
plt.subplot(122)
sns.displot(df['placement_exam_marks'])
plt.show()

# %%
sns.boxplot(x=df['placement_exam_marks'])
# Out:
# <Axes: xlabel='placement_exam_marks'>

# %%
# finding the IRQ

percentile25=df['placement_exam_marks'].quantile(0.25)
percentile75=df['placement_exam_marks'].quantile(0.75)

# %%
percentile25
# Out:
# 17.0

# %%
percentile75
# Out:
# 44.0

# %%
IQR=percentile75-percentile25
IQR
# Out:
# 27.0

# %%
upper_limit=percentile75+1.5*IQR
upper_limit
# Out:
# 84.5

# %%
lower_limit=percentile25-1.5*IQR
lower_limit
# Out:
# -23.5

# %% [markdown]
# # finding our Outliers

# %%
df[df['placement_exam_marks']>upper_limit]
# Out:
#      cgpa  placement_exam_marks  placed
# 9    7.75                    94       1
# 40   6.60                    86       1
# 61   7.51                    86       0
# 134  6.33                    93       0
# 162  7.80                    90       0
# 283  7.09                    87       0
# 290  8.38                    87       0
# 311  6.97                    87       1
# 324  6.64                    90       0
# 630  6.56                    96       1
# 685  6.05                    87       1
# 730  6.14                    90       1
# 771  7.31                    86       1
# 846  6.99                    97       0
# 917  5.95                   100       0

# %%
df[df['placement_exam_marks']<lower_limit]
# Out:
# Empty DataFrame
# Columns: [cgpa, placement_exam_marks, placed]
# Index: []

# %%
# Trimming (outlier Removing technique 1)

# %%
newdf =df[df['placement_exam_marks'
# Out:
#   Cell In[19], line 1
#     newdf =df[df['placement_exam_marks'
#                                        ^
# SyntaxError: incomplete input

# %%
#Comparision

# %%
plt.figure(figsize=(15,5))
plt.subplot(221)
sns.displot(df['placement_exam_marks'])

plt.subplot(222)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(223)
sns.displot(newdf['placement_exam_marks'])

plt.subplot(224)
sns.boxplot(newdf['placement_exam_marks'])
plt.show()

# %% [markdown]
# # Capping(Outlier Removing technique 2)

# %%
new_df_cap=df.copy()

# %%
# min =5, max=15

# min 4, 3, 1
#max= 20,30,50
#updated_min_value=1
#updated max_value=50

# %%
new_df_cap['placement_exam_marks']=np.where(
    new_df_cap['placement_exam_marks'] > upper_limit,
    upper_limit,

    np.where(
        new_df_cap['placement_exam_marks']<lower_limit,
        lower_limit,
        new_df_cap['placement_exam_marks'])
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 new_df_cap['placement_exam_marks']=np.where(
# ----> 2     new_df_cap['placement_exam_marks'] > upper_limit,
#       3     upper_limit,
#       4
#       5     np.where(
#       6         new_df_cap['placement_exam_marks']<lower_limit,
#       7         lower_limit,
#       8         new_df_cap['placement_exam_marks'])
#       9 )
#
# NameError: name 'new_df_cap' is not defined

# %%
new_df_cap.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 new_df_cap.shape
#
# NameError: name 'new_df_cap' is not defined

# %% [markdown]
# # comparision

# %%
plt.figure(figsize=(15,8))
plt.subplot(221)
sns.displot(df['placement
